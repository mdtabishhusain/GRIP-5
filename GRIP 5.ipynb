# %% [markdown]
# By: Mohd Tabish Husain
#
# Data Science and Business Analyst Internship at The Sparks Foundation (September 2022)
#
# Task 5 - Prediction using decision tree algorithm

# %% [markdown]
# # Step 1 - Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris, load_boston
from sklearn import tree

# %% [markdown]
# # Step 2 - Loading and printing IRIS dataset

# %%
df=load_iris()

# %% [markdown]
# # Step 3 - Assigning training and test data

# %%
x = iris.data
y = iris.target
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

#fit
treemodel = tree.DecisionTreeClassifier(max_depth=3, random_state=42)
treemodel.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %% [markdown]
# # Step 4 - Plotting data on decision tree

# %%
from sklearn import tree
plt.figure(figsize=(15,10))
tree=tree.plot_tree(treemodel,feature_names = iris.feature_names, 
               class_names=iris.target_names,
               rounded=True,filled=True)

# %% [markdown]
# # Making Predictions

# %%
y_pred=treemodel.predict(x_test)
y_pred
# Out:
# array([1, 0, 2, 1, 1, 0, 1, 2, 1, 1, 2, 0, 0, 0, 0, 1, 2, 1, 1, 2, 0, 2,
#        0, 2, 2, 2, 2, 2, 0, 0])

# %%
from sklearn.metrics import accuracy_score,classification_report
score=accuracy_score(y_pred,y_test)
score
# Out:
# 1.0

# %%
report=classification_report(y_pred,y_test)
print (report)
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
